# %%
import pandas as pd
import numpy as np

# %matplotlib inline

# %%
df = pd.read_csv("data_cleaned_ready_to_join.csv", sep='\t')
df.head()
# Out:
#     Marke               Marke_und_Typ                 Typ1      Typ2     Typ3  \
# 0  ABARTH  ABARTH ZAGATO 750 GT CORSA  Zagato 750 GT Corsa    Zagato      750
# 1  ABARTH           ABARTH 1300-104 S           1300-104 S  1300-104        S
# 2  ABARTH           ABARTH 1300-104 S           1300-104 S  1300-104        S
# 3  ABARTH  ABARTH 500 OPENING EDITION  500 Opening Edition       500  Opening
# 4  ABARTH  ABARTH 500 OPENING EDITION  500 Opening Edition       500  Opening
#
#        Typ4    CO2  Erstinverkehrsetzung_Jahr   PLZ                Ort  \
# 0  GT Corsa    NaN                       1957  6403  Küssnacht am Rigi
# 1       NaN    NaN                       1969  3176           Neuenegg
# 2       NaN    NaN                       1970  8152         Glattbrugg
# 3   Edition    NaN                       2008  1117             Grancy
# 4   Edition  155.0                       2016  1261           Longirod
#
#    BFS-Gemeinde-Nr Halterart
# 0             1331         m
# ...

# %%
df1 = pd.read_csv("new_categories_cars.csv")
df1
# Out:
#                Modellreihe     Segment
# 0              AUSTIN MINI       MINIS
# 1          CHEVROLET MATIZ       MINIS
# 2          CHEVROLET SPARK       MINIS
# 3               CITROEN C1       MINIS
# 4           DAIHATSU CUORE       MINIS
# 5            DAIHATSU MOVE       MINIS
# 6          DAIHATSU TREVIS       MINIS
# 7         FIAT CINQUECENTO       MINIS
# 8               FIAT PANDA       MINIS
# 9            FIAT SEICENTO       MINIS
# 10                FIAT 500       MINIS
# 11                 FORD KA       MINIS
# 12            HYUNDAI ATOS       MINIS
# 13            HYUNDAI I 10       MINIS
# 14             KIA PICANTO       MINIS
# 15          LANCIA YPSILON       MINIS
# 16       MITSUBISHI I-MIEV       MINIS
# 17             NISSAN PIXO       MINIS
# 18               OPEL ADAM       MINIS
# 19              OPEL AGILA       MINIS
# 20               OPEL KARL       MINIS
# 21             PEUGEOT ION       MINIS
# 22             PEUGEOT 106       MINIS
# ...

# %%
df1 = df1.rename(columns={'Modellreihe': 'Marke_und_Typ'})
df1.head()

# df1['Marke_und_Typ'] = df1['Marke_und_Typ'].astype(str).str.strip().apply(lambda s: s[2:-1])
df1.dtypes
df1.head()
# Out:
#      Marke_und_Typ Segment
# 0      AUSTIN MINI   MINIS
# 1  CHEVROLET MATIZ   MINIS
# 2  CHEVROLET SPARK   MINIS
# 3       CITROEN C1   MINIS
# 4   DAIHATSU CUORE   MINIS

# %%
## remove the chunk from the rows/strings

s=set(df1['Marke_und_Typ']) #& set(df['Marke_und_Typ'])
set(map(lambda ss : ss[2:-1], s))
# Out:
# {' ARTEO',
#  ' BEETL',
#  ' CADD',
#  ' CORRAD',
#  ' CRAFTE',
#  ' DS',
#  ' EO',
#  ' FO',
#  ' GOL',
#  ' JETT',
#  ' L',
#  ' LUP',
#  ' PASSA',
#  ' PHAETO',
#  ' POL',
#  ' ROVER 2',
#  ' ROVER 4',
#  ' ROVER 600-REIH',
#  ' ROVER 7',
#  ' ROVER MG',
#  ' ROVER T',
#  ' ROVER Z',
#  ' SCIROCC',
#  ' SHARA',
#  ' T-RO',
#  ' TIGUA',
#  ' TOUARE',
#  ' TOURA',
#  ' TRANSPORTE',
#  ' TYP ',
#  ' U',
#  'A CAREN',
#  'A CARNIVA',
#  'A CEE',
#  'A CERAT',
#  'A MAGENTI',
#  'A NIR',
#  'A OPIRU',
#  'A OPTIM',
#  'A PICANT',
#  'A PRID',
#  'A RI',
#  'A SEPHI',
#  'A SHUM',
#  'A SORENT',
#  'A SOU',
#  'A SPORTAG',
#  'A STONI',
#  'A VENG',
#  'AB 9-',
#  'AB 900',
#  'ANGYONG KORAND',
#  'ANGYONG REXTO',
#  'ANGYONG TIVOL',
#  'ART FORFOU',
#  'ART FORTW',
#  'ART ROADSTE',
#  'AT 124 SPIDE',
#  'AT 50',
#  'AT ALHAMBR',
#  'AT ALTE',
#  'AT AROS',
#  'AT ATEC',
#  'AT BARCHETT',
#  'AT BRAV',
#  'AT CINQUECENT',
#  'AT CORDOB',
#  'AT COUP',
#  'AT CROM',
#  'AT DOBL',
# ...

# %%
df3 = df.merge(df1,how='left', left_on='Marke_und_Typ', right_on='Marke_und_Typ')
df3.head(50)
# Out:
#           Marke               Marke_und_Typ                   Typ1  \
# 0        ABARTH  ABARTH ZAGATO 750 GT CORSA    Zagato 750 GT Corsa
# 1        ABARTH           ABARTH 1300-104 S             1300-104 S
# 2        ABARTH           ABARTH 1300-104 S             1300-104 S
# 3        ABARTH  ABARTH 500 OPENING EDITION    500 Opening Edition
# 4        ABARTH  ABARTH 500 OPENING EDITION    500 Opening Edition
# 5        ABARTH                  ABARTH 500                    500
# 6        ABARTH          ABARTH 500 BIPOSTO            500 Biposto
# 7        ABARTH     ABARTH 595C TURISMO 165       595C Turismo 165
# 8        ABARTH     ABARTH 595C TURISMO 165       595C Turismo 165
# 9   AB KAWASAKI  AB KAWASAKI MULE 4010 D TR         Mule 4010 D Tr
# 10  AB KAWASAKI  AB KAWASAKI MULE 4010 D TR         Mule 4010 D Tr
# 11  AB KAWASAKI  AB KAWASAKI MULE 4010 D TR         Mule 4010 D Tr
# 12  AB KAWASAKI  AB KAWASAKI MULE 4010 D TR         Mule 4010 D Tr
# ...

# %%
df3.count()
# Out:
# Marke                        4565241
# Marke_und_Typ                4565241
# Typ1                         4562670
# Typ2                         4562668
# Typ3                         3913244
# Typ4                         2283995
# CO2                          4176311
# Erstinverkehrsetzung_Jahr    4565241
# PLZ                          4565241
# Ort                          4565241
# BFS-Gemeinde-Nr              4565241
# Halterart                    4565241
# Segment                       425935
# dtype: int64

# %%
df3.isna().sum()
# Out:
# Marke                              0
# Marke_und_Typ                      0
# Typ1                            2571
# Typ2                            2573
# Typ3                          651997
# Typ4                         2281246
# CO2                           388930
# Erstinverkehrsetzung_Jahr          0
# PLZ                                0
# Ort                                0
# BFS-Gemeinde-Nr                    0
# Halterart                          0
# Segment                      4139306
# dtype: int64

# %%
df3.shape
# Out:
# (4565241, 13)

# %%
df4 = df3[['Marke_und_Typ','Erstinverkehrsetzung_Jahr', 'BFS-Gemeinde-Nr', 'Halterart', 'Segment']]

# %%
df4.head()
# Out:
#                 Marke_und_Typ  Erstinverkehrsetzung_Jahr  BFS-Gemeinde-Nr  \
# 0  ABARTH ZAGATO 750 GT CORSA                       1957             1331
# 1           ABARTH 1300-104 S                       1969              670
# 2           ABARTH 1300-104 S                       1970               66
# 3  ABARTH 500 OPENING EDITION                       2008             5485
# 4  ABARTH 500 OPENING EDITION                       2016             5429
#
#   Halterart Segment
# 0         m     NaN
# 1         m     NaN
# 2         w     NaN
# 3         w     NaN
# 4         w     NaN

# %%
df4.Segment.value_counts()
# Out:
# KOMPAKTKLASSE         120975
# KLEINWAGEN            103342
# SUV                    36099
# GROSSRAUM-VANS         35721
# GELÄNDEWAGEN           34012
# MINIS                  26961
# MITTELKLASSE           21904
# MINI-VANS              17577
# SPORTWAGEN             12273
# UTILITIES               9472
# OBERE MITTELKLASSE      4630
# OBERKLASSE              2199
# WOHNMOBILE               770
# Name: Segment, dtype: int64

# %%
df5 = df4[df4['Segment'].isin(['SUV', 'GELÄNDEWAGEN'])]

# %%
df5.head()
# Out:
#             Marke_und_Typ  Erstinverkehrsetzung_Jahr  BFS-Gemeinde-Nr  \
# 44542  ALFA ROMEO STELVIO                       2017             3231
# 44617  ALFA ROMEO STELVIO                       2018             6082
# 44820  ALFA ROMEO STELVIO                       2017             5398
# 44945  ALFA ROMEO STELVIO                       2017             3254
# 44958  ALFA ROMEO STELVIO                       2018             1631
#
#       Halterart Segment
# 44542         w     SUV
# 44617         m     SUV
# 44820         w     SUV
# 44945         m     SUV
# 44958         m     SUV

# %%
df5['Gemeindecode'] = df5['BFS-Gemeinde-Nr']
# Out:
# C:\Users\Dominik Balmer\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df5.head()
# Out:
#             Marke_und_Typ  Erstinverkehrsetzung_Jahr  BFS-Gemeinde-Nr  \
# 44542  ALFA ROMEO STELVIO                       2017             3231
# 44617  ALFA ROMEO STELVIO                       2018             6082
# 44820  ALFA ROMEO STELVIO                       2017             5398
# 44945  ALFA ROMEO STELVIO                       2017             3254
# 44958  ALFA ROMEO STELVIO                       2018             1631
#
#       Halterart Segment  Gemeindecode
# 44542         w     SUV          3231
# 44617         m     SUV          6082
# 44820         w     SUV          5398
# 44945         m     SUV          3254
# 44958         m     SUV          1631

# %%
df5.to_csv('suv_def.csv')

# %% [markdown]
# ## Merge df5 with the dataframe with population

# %%
comm = pd.read_csv('local_communities.csv', dtype={"Einwohner":str})

# %%
comm.head()
# Out:
#    Gemeindecode        Gemeindename Einwohner
# 0             1     Aeugst am Albis     1.941
# 1             2  Affoltern am Albis    12.146
# 2             3          Bonstetten     5.512
# 3             4     Hausen am Albis     3.664
# 4             5            Hedingen     3.694

# %%
comm['Einwohner'] = comm.Einwohner.str.replace(".","").astype(int)

# %%
comm.head()
# Out:
#    Gemeindecode        Gemeindename  Einwohner
# 0             1     Aeugst am Albis       1941
# 1             2  Affoltern am Albis      12146
# 2             3          Bonstetten       5512
# 3             4     Hausen am Albis       3664
# 4             5            Hedingen       3694

# %%
comm.dtypes
# Out:
# Gemeindecode     int64
# Gemeindename    object
# Einwohner        int32
# dtype: object

# %%
merged = df5.merge(comm, on='Gemeindecode')

# %%
merged.head()
# Out:
#         Marke_und_Typ  Erstinverkehrsetzung_Jahr  BFS-Gemeinde-Nr Halterart  \
# 0  ALFA ROMEO STELVIO                       2017             3231         w
# 1             AUDI Q5                       2016             3231         m
# 2             AUDI Q5                       2012             3231         j
# 3             AUDI Q5                       2012             3231         w
# 4             AUDI Q5                       2013             3231         m
#
#         Segment  Gemeindecode Gemeindename  Einwohner
# 0           SUV          3231      Au (SG)       7622
# 1  GELÄNDEWAGEN          3231      Au (SG)       7622
# 2  GELÄNDEWAGEN          3231      Au (SG)       7622
# 3  GELÄNDEWAGEN          3231      Au (SG)       7622
# 4  GELÄNDEWAGEN          3231      Au (SG)       7622

# %%
merged.shape
# Out:
# (69819, 8)

# %%
merged.to_csv('suv_def_merged_2407.csv')

# %% [markdown]
# # Some nice charts

# %%
merged.groupby('Gemeindename').Segment.value_counts().sort_values(ascending=False).head(10)
# Out:
# Gemeindename  Segment
# Genève        GELÄNDEWAGEN    1108
# Zürich        GELÄNDEWAGEN    1063
#               SUV              937
# Genève        SUV              891
# Lugano        SUV              437
# Bern          GELÄNDEWAGEN     418
# Basel         GELÄNDEWAGEN     411
# Lausanne      SUV              393
# Lugano        GELÄNDEWAGEN     332
# Basel         SUV              320
# Name: Segment, dtype: int64

# %% [markdown]
# # Municipalities with the most SUV (absolute values)

# %%
suv = merged[merged['Segment'] == 'SUV']

# %%
suv.groupby('Gemeindename').Segment.value_counts().sort_values(ascending=False).head(10).sort_values().plot(kind='barh')

# %% [markdown]
# # Municipalities with the most Geländewagen (absolute values)

# %%
offroader = merged[merged['Segment'] == 'GELÄNDEWAGEN']

# %%
offroader.groupby('Gemeindename').Segment.value_counts().sort_values(ascending=False).head(10).sort_values().plot(kind='barh')

# %% [markdown]
# # Municipalities with the most SUV/Geländewagen

# %%
merged.Gemeindename.value_counts().head(10).sort_values().plot(kind='barh')

# %% [markdown]
# # Calculate the SUV Quota per Municipality and per 1000 Inhabitants

# %%
merged.columns
# Out:
# Index(['Marke_und_Typ', 'Erstinverkehrsetzung_Jahr', 'BFS-Gemeinde-Nr',
#        'Halterart', 'Segment', 'Gemeindecode', 'Gemeindename', 'Einwohner'],
#       dtype='object')

# %%
merged.sort_values("Gemeindename").head()
# Out:
#         Marke_und_Typ  Erstinverkehrsetzung_Jahr  BFS-Gemeinde-Nr Halterart  \
# 43462          BMW X3                       2012             4551         j
# 43503  NISSAN QASHQAI                       2015             4551         m
# 43502  NISSAN QASHQAI                       2012             4551         m
# 43460         AUDI Q3                       2015             4551         j
# 43461         AUDI Q5                       2017             4551         m
#
#             Segment  Gemeindecode Gemeindename  Einwohner
# 43462  GELÄNDEWAGEN          4551       Aadorf       8885
# 43503           SUV          4551       Aadorf       8885
# 43502           SUV          4551       Aadorf       8885
# 43460  GELÄNDEWAGEN          4551       Aadorf       8885
# 43461  GELÄNDEWAGEN          4551       Aadorf       8885

# %%
merged.groupby(['Gemeindename']).Einwohner.agg([("name",lambda x: len(x)/np.mean(x)*1000)])
# Out:
#                               name
# Gemeindename
# Aadorf                    8.891390
# Aarau                     6.347564
# Aarberg                   6.767081
# Aarburg                   6.073376
# Aarwangen                 9.525919
# Abtwil                    7.172131
# Aclens                   18.382353
# Acquarossa               13.513514
# Adelboden                12.162563
# Adligenswil               6.176305
# Adlikon                   4.511278
# Adliswil                  8.456097
# Aedermannsdorf            8.741259
# Aefligen                  9.165903
# Aegerten                  3.898635
# Aesch (BL)                8.400899
# Aesch (LU)               14.937759
# Aesch (ZH)                5.192878
# Aeschi (SO)               8.190008
# Aeschi bei Spiez         11.816193
# Aeugst am Albis          11.334364
# Affeltrangen             12.099922
# Affoltern am Albis        5.763214
# Affoltern im Emmental    15.004413
# Agarn                     6.553080
# ...

# %%
df6 = merged.groupby(['Gemeindename']).Einwohner.agg([("name",lambda x: len(x)/np.mean(x)*1000)])

# %%
df6.head()
# Out:
#                   name
# Gemeindename
# Aadorf        8.891390
# Aarau         6.347564
# Aarberg       6.767081
# Aarburg       6.073376
# Aarwangen     9.525919

# %%
df6.to_csv('all_suv_per_municipality.csv')

# %% [markdown]
# # Top ten municipalities with suv per 1000 inhabitants

# %%
df6 = pd.read_csv("all_suv_per_municipality.csv")
df6.head()
# Out:
#   Gemeindename      name
# 0       Aadorf  8.891390
# 1        Aarau  6.347564
# 2      Aarberg  6.767081
# 3      Aarburg  6.073376
# 4    Aarwangen  9.525919

# %%
df6.name.sort_values(ascending=False).head(10).sort_values().plot(kind='barh')

# %%
df6.name.sort_values(ascending=False).head(10)
# Out:
# 422     83.333333
# 2035    64.102564
# 622     53.658537
# 1584    48.387097
# 1739    47.619048
# 1069    45.170591
# 397     43.478261
# 1858    42.424242
# 1901    40.880503
# 754     40.201005
# Name: name, dtype: float64

# %% [markdown]
# # Last ten municipalities with suv per 1000 inhabitants

# %%
df6.name.sort_values().head(10).sort_values().plot(kind='barh')

# %% [markdown]
# # Merge df6 with the Gemeindecode

# %%
df6.head()
# Out:
#                   name
# Gemeindename
# Aadorf        8.891390
# Aarau         6.347564
# Aarberg       6.767081
# Aarburg       6.073376
# Aarwangen     9.525919

# %%
merged.head()
# Out:
#         Marke_und_Typ  Erstinverkehrsetzung_Jahr  BFS-Gemeinde-Nr Halterart  \
# 0  ALFA ROMEO STELVIO                       2017             3231         w
# 1             AUDI Q5                       2016             3231         m
# 2             AUDI Q5                       2012             3231         j
# 3             AUDI Q5                       2012             3231         w
# 4             AUDI Q5                       2013             3231         m
#
#         Segment  Gemeindecode Gemeindename  Einwohner
# 0           SUV          3231      Au (SG)       7622
# 1  GELÄNDEWAGEN          3231      Au (SG)       7622
# 2  GELÄNDEWAGEN          3231      Au (SG)       7622
# 3  GELÄNDEWAGEN          3231      Au (SG)       7622
# 4  GELÄNDEWAGEN          3231      Au (SG)       7622

# %%
df7 = merged.merge(df6, on='Gemeindename')

# %%
df7.head()
# Out:
#         Marke_und_Typ  Erstinverkehrsetzung_Jahr  BFS-Gemeinde-Nr Halterart  \
# 0  ALFA ROMEO STELVIO                       2017             3231         w
# 1             AUDI Q5                       2016             3231         m
# 2             AUDI Q5                       2012             3231         j
# 3             AUDI Q5                       2012             3231         w
# 4             AUDI Q5                       2013             3231         m
#
#         Segment  Gemeindecode Gemeindename  Einwohner       name
# 0           SUV          3231      Au (SG)       7622  11.283128
# 1  GELÄNDEWAGEN          3231      Au (SG)       7622  11.283128
# 2  GELÄNDEWAGEN          3231      Au (SG)       7622  11.283128
# 3  GELÄNDEWAGEN          3231      Au (SG)       7622  11.283128
# 4  GELÄNDEWAGEN          3231      Au (SG)       7622  11.283128

# %%
df7.to_csv('ready_for_qgis.csv')

# %% [markdown]
# ## Read in again

# %%
df7 = pd.read_csv("ready_for_qgis.csv")
df7.head()
# Out:
#    Unnamed: 0       Marke_und_Typ  Erstinverkehrsetzung_Jahr  BFS-Gemeinde-Nr  \
# 0           0  ALFA ROMEO STELVIO                       2017             3231
# 1           1             AUDI Q5                       2016             3231
# 2           2             AUDI Q5                       2012             3231
# 3           3             AUDI Q5                       2012             3231
# 4           4             AUDI Q5                       2013             3231
#
#   Halterart       Segment  Gemeindecode Gemeindename  Einwohner       name
# 0         w           SUV          3231      Au (SG)       7622  11.283128
# 1         m  GELÄNDEWAGEN          3231      Au (SG)       7622  11.283128
# 2         j  GELÄNDEWAGEN          3231      Au (SG)       7622  11.283128
# 3         w  GELÄNDEWAGEN          3231      Au (SG)       7622  11.283128
# 4         m  GELÄNDEWAGEN          3231      Au (SG)       7622  11.283128

# %% [markdown]
# ## most popular suv/offroader in switzerland

# %%
df7.Marke_und_Typ.value_counts().head(10).plot(kind='bar', figsize=(10,5), color='#007ACC')

plt.savefig("brands_top_ten.pdf")

# %% [markdown]
# ## take out only municipalities with more than 500 inhabitants

# %%
df8 = df7[df7.Einwohner > 500]

# %%
df8.head()
# Out:
#    Unnamed: 0       Marke_und_Typ  Erstinverkehrsetzung_Jahr  BFS-Gemeinde-Nr  \
# 0           0  ALFA ROMEO STELVIO                       2017             3231
# 1           1             AUDI Q5                       2016             3231
# 2           2             AUDI Q5                       2012             3231
# 3           3             AUDI Q5                       2012             3231
# 4           4             AUDI Q5                       2013             3231
#
#   Halterart       Segment  Gemeindecode Gemeindename  Einwohner       name
# 0         w           SUV          3231      Au (SG)       7622  11.283128
# 1         m  GELÄNDEWAGEN          3231      Au (SG)       7622  11.283128
# 2         j  GELÄNDEWAGEN          3231      Au (SG)       7622  11.283128
# 3         w  GELÄNDEWAGEN          3231      Au (SG)       7622  11.283128
# 4         m  GELÄNDEWAGEN          3231      Au (SG)       7622  11.283128

# %%
df9 = df8.groupby('Gemeindename').first()
df9.head()
# Out:
#               Unnamed: 0 Marke_und_Typ  Erstinverkehrsetzung_Jahr  \
# Gemeindename
# Aadorf             43457       AUDI Q5                       2012
# Aarau               5909       AUDI Q7                       2007
# Aarberg            67523    HONDA CR-V                       1999
# Aarburg            46592       AUDI Q5                       2013
# Aarwangen          42795       AUDI Q5                       2011
#
#               BFS-Gemeinde-Nr Halterart       Segment  Gemeindecode  \
# Gemeindename
# Aadorf                   4551         m  GELÄNDEWAGEN          4551
# Aarau                    4001         m  GELÄNDEWAGEN          4001
# Aarberg                   301         w           SUV           301
# Aarburg                  4271         w  GELÄNDEWAGEN          4271
# Aarwangen                 321         m  GELÄNDEWAGEN           321
#
#               Einwohner      name
# Gemeindename
# Aadorf             8885  8.891390
# Aarau             21268  6.347564
# ...

# %% [markdown]
# # top ten municipalities with more than 500 inhabitants

# %%
import matplotlib.pyplot as plt

# %%
df9.name.mean()
# Out:
# 10.067793894085042

# %%
df9.name.sort_values(ascending=False).head(5).sort_values().plot(kind='barh', figsize=(10,5), color='brown',
title='These People Like SUV Top Ten Municipalities: SUV/Offroader per 1000 Inhabitants (only Municipalities with more than 500 Inhabitants)')

plt.xlim([0, 50])

ax = plt.gca()
ax.grid(which='major', axis='x', linestyle='--')

# %%
df9.name.sort_values().head(5).sort_values().plot(kind='barh', figsize=(10,5), color='brown',
title="These People don't like SUV Top Ten Municipalities: SUV/Offroader per 1000 Inhabitants (only Municipalities with more than 500 Inhabitants)")

plt.xlim([0, 50])

ax = plt.gca()
ax.grid(which='major', axis='x', linestyle='--')

# %%
df9.name.sort_values(ascending=False).head(5).sort_values().plot(kind='barh', figsize=(10,5), color='brown',
title='These People Like SUV Top Ten Municipalities: SUV/Offroader per 1000 Inhabitants (only Municipalities with more than 500 Inhabitants)')

df9.name.sort_values().head(5).sort_values().plot(kind='barh', figsize=(10,5), color='brown',
title="These People don't like SUV Top Ten Municipalities: SUV/Offroader per 1000 Inhabitants (only Municipalities with more than 500 Inhabitants)")

plt.xlim([0, 50])

ax = plt.gca()
ax.grid(which='major', axis='x', linestyle='--')

# %%
fig, axis_array = plt.subplots(2, 1, sharex=True)

df9.name.sort_values(ascending=False).head(5).sort_values().plot(ax=axis_array[0], kind='barh', color='brown')
df9.name.sort_values().head(5).sort_values().plot(ax=axis_array[1], kind='barh', color='brown')

plt.xlim([0, 50])

ax = plt.gca()
ax.grid(which='major', axis='x', linestyle='--')

fig.tight_layout()

# %%
df10 = df9.name.sort_values(ascending=False).head(5).sort_values()

# %%
b = df9.name.sort_values().head(5).sort_values(ascending=False)

# %%
df10 = df10.append(b)

# %%
df10.sort_values().plot(kind='barh', figsize=(10,5), color='#007ACC', alpha=0.2, linewidth=5)

plt.xlim([0, 50])

ax = plt.gca()
ax.grid(which='major', axis='x', linestyle='--')

# %%
df10
# Out:
# Gemeindename
# Airolo        29.469548
# S-chanf       30.656934
# Evolène       31.746032
# Homberg       32.504780
# Lens          45.170591
# Dägerlen       1.970443
# Baulmes        1.893939
# Denens         1.291990
# Illgau         1.254705
# Lavertezzo     0.752445
# Name: name, dtype: float64

# %%
df7
# Out:
#        Unnamed: 0       Marke_und_Typ  Erstinverkehrsetzung_Jahr  \
# 0               0  ALFA ROMEO STELVIO                       2017
# 1               1             AUDI Q5                       2016
# 2               2             AUDI Q5                       2012
# 3               3             AUDI Q5                       2012
# 4               4             AUDI Q5                       2013
# 5               5             AUDI Q5                       2011
# 6               6              BMW X6                       2010
# 7               7              BMW X6                       2010
# 8               8              BMW X6                       2011
# 9               9              BMW X6                       2012
# 10             10              BMW X6                       2011
# 11             11              BMW X6                       2012
# 12             12              BMW X3                       2016
# ...

# %%
df10.T
# Out:
# Gemeindename
# Lavertezzo     0.752445
# Illgau         1.254705
# Denens         1.291990
# Baulmes        1.893939
# Dägerlen       1.970443
# Airolo        29.469548
# S-chanf       30.656934
# Evolène       31.746032
# Homberg       32.504780
# Lens          45.170591
# Name: name, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# set font
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Helvetica'

# set the style of the axes and the text color
plt.rcParams['axes.edgecolor']='#333F4B'
plt.rcParams['axes.linewidth']=0.8
plt.rcParams['xtick.color']='#333F4B'
plt.rcParams['ytick.color']='#333F4B'
plt.rcParams['text.color']='#333F4B'

# create some fake data
percentages = df10
df10 = df10.sort_values()

# we first need a numeric placeholder for the y axis
my_range=list(range(1,len(df10.index)+1))

fig, ax = plt.subplots(figsize=(13,3.5))

# create for each expense type an horizontal line that starts at x = 0 with the length 
# represented by the specific expense percentage value.
plt.hlines(y=my_range, xmin=0, xmax=df10, color='#007ACC', alpha=0.2, linewidth=5)

# create for each expense type a dot at the level of the expense percentage value
plt.plot(df10, my_range, "o", markersize=5, color='#007ACC', alpha=0.6)

# set labels
ax.set_xlabel('SUV/Offroader Per 1000 Inhabitants', fontsize=15, fontweight='black', color = '#333F4B')
ax.set_ylabel('')

# set axis
ax.tick_params(axis='both', which='major', labelsize=12)
plt.yticks(my_range, df10.index)

# add an horizonal label for the y axis 
# fig.text(-0.23, 0.96, 'Municipality', fontsize=15, fontweight='black', color = '#333F4B')

# change the style of the axis spines
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')
ax.spines['left'].set_smart_bounds(True)
ax.spines['bottom'].set_smart_bounds(True)

# set the spines position
ax.spines['bottom'].set_position(('axes', -0.04))
ax.spines['left'].set_position(('axes', 0.015))


plt.tight_layout()
plt.savefig('nnnew_bar_suv_per_1000.pdf')
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Helvetica'

# set the style of the axes and the text color
plt.rcParams['axes.edgecolor']='#333F4B'
plt.rcParams['axes.linewidth']=0.8
plt.rcParams['xtick.color']='#333F4B'
plt.rcParams['ytick.color']='#333F4B'
plt.rcParams['text.color']='#333F4B'

# create some fake data
percentages = df7
df7 = df7.sort_values().head(10)

# df7.Marke_und_Typ.value_counts().head(10)

# we first need a numeric placeholder for the y axis
my_range=list(range(1,len(df7.index)+1))

fig, ax = plt.subplots(figsize=(13,3.5))

# create for each expense type an horizontal line that starts at x = 0 with the length 
# represented by the specific expense percentage value.
plt.hlines(y=my_range, xmin=0, xmax=df7, color='#007ACC', alpha=0.2, linewidth=5)

# create for each expense type a dot at the level of the expense percentage value
plt.plot(df7, my_range, "o", markersize=5, color='#007ACC', alpha=0.6)

# set labels
ax.set_xlabel('The Most Popular SUV Brands in Switzerland', fontsize=15, fontweight='black', color = '#333F4B')
ax.set_ylabel('')

# set axis
ax.tick_params(axis='both', which='major', labelsize=12)
plt.yticks(my_range, df7.index)

# add an horizonal label for the y axis 
# fig.text(-0.23, 0.96, 'Municipality', fontsize=15, fontweight='black', color = '#333F4B')

# change the style of the axis spines
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')
ax.spines['left'].set_smart_bounds(True)
ax.spines['bottom'].set_smart_bounds(True)

# set the spines position
ax.spines['bottom'].set_position(('axes', -0.04))
ax.spines['left'].set_position(('axes', 0.015))


plt.tight_layout()
plt.savefig('brands1000_newww.pdf')
